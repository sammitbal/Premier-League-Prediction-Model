# %% [markdown]
# Squad Standard Stats table

# %%
import pandas as pd

# %%
df = pd.read_html('https://fbref.com/en/comps/9/Premier-League-Stats',
                  attrs={"id":"stats_squads_standard_for"}) [0]

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                Squad               # Pl                Age               Poss
# 0            Arsenal                 23               26.4               54.4
# 1        Aston Villa                 23               27.5               50.5
# 2        Bournemouth                 25               26.0               45.3
# 3          Brentford                 23               26.5               46.9
# 4           Brighton                 28               25.8               53.4
#
#   Playing Time                    Performance      ... Per 90 Minutes        \
#             MP Starts   Min   90s         Gls Ast  ...            Gls   Ast
# 0           16    176  1440  16.0          28  23  ...           1.75  1.44
# 1           16    176  1440  16.0          23  18  ...           1.44  1.13
# 2           16    176  1440  16.0          24  16  ...           1.50  1.00
# ...

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0             Arsenal                 25               25.0
# 1         Aston Villa                 31               26.9
# 2         Bournemouth                 30               25.7
# 3           Brentford                 28               26.6
# 4            Brighton                 30               25.9
# 5             Burnley                 31               24.5
# 6             Chelsea                 32               24.2
# 7      Crystal Palace                 26               26.7
# 8             Everton                 26               27.1
# 9              Fulham                 25               28.4
# 10          Liverpool                 30               26.3
# 11         Luton Town                 28               26.7
# 12    Manchester City                 25               26.6
# 13     Manchester Utd                 31               26.1
# ...

# %%
df.columns = ['_'.join(col).strip() for col in df.columns.values]

# %%
from google.colab import files

df.to_csv('df.csv')
files.download('df.csv')

# %% [markdown]
# Squad Goal and Shot Creation table

# %%
st = pd.read_html('https://fbref.com/en/comps/9/Premier-League-Stats',
                  attrs={"id":"stats_squads_gca_for"}) [0]

# %%
pd.set_option('display.max_columns', None)

# %%
st.columns = ['_'.join(col).strip() for col in st.columns.values]

# %%
st
# Out:
#    Unnamed: 0_level_0_Squad  Unnamed: 1_level_0_# Pl  Unnamed: 2_level_0_90s  \
# 0                   Arsenal                       25                    38.0
# 1               Aston Villa                       31                    38.0
# 2               Bournemouth                       30                    38.0
# 3                 Brentford                       28                    38.0
# 4                  Brighton                       30                    38.0
# 5                   Burnley                       31                    38.0
# 6                   Chelsea                       32                    38.0
# 7            Crystal Palace                       26                    38.0
# 8                   Everton                       26                    38.0
# 9                    Fulham                       25                    38.0
# 10                Liverpool                       30                    38.0
# ...

# %%
from google.colab import files

st.to_csv('SquadGoalandShotCreation.csv')
files.download('SquadGoalandShotCreation.csv')

# %% [markdown]
# Squad Wages

# %%
wg = pd.read_html('https://fbref.com/en/comps/9/wages/Premier-League-Wages',
                  attrs={"id":"squad_wages"}) [0]

# %%
pd.set_option('display.max_columns', None)

# %%
wg.columns = ['_'.join(col).strip() for col in wg.columns.values]

# %%
wg
# Out:
#     R_k        S_q_u_a_d  #_ _P_l                W_e_e_k_l_y_ _W_a_g_e_s  \
# 0     1   Manchester Utd       57  £ 3,956,846 (€ 4,597,795, $4,901,914)
# 1     2  Manchester City       48  £ 3,866,000 (€ 4,492,233, $4,789,369)
# 2     3          Arsenal       52  £ 3,193,000 (€ 3,710,217, $3,955,628)
# 3     4          Chelsea       60  £ 3,020,000 (€ 3,509,194, $3,741,308)
# 4     5        Liverpool       49  £ 2,620,000 (€ 3,044,400, $3,245,770)
# 5     6        Tottenham       61  £ 2,260,000 (€ 2,626,086, $2,799,787)
# 6     7      Aston Villa       52  £ 2,252,885 (€ 2,617,818, $2,790,972)
# 7     8         West Ham       46  £ 1,833,000 (€ 2,129,918, $2,270,800)
# 8     9    Newcastle Utd       57  £ 1,625,000 (€ 1,888,225, $2,013,121)
# 9    10          Everton       46  £ 1,518,808 (€ 1,764,831, $1,881,565)
# 10   11  Nott'ham Forest       72  £ 1,385,577 (€ 1,610,019, $1,716,513)
# 11   12   Crystal Palace       53  £ 1,327,885 (€ 1,542,982, $1,645,041)
# ...

# %%
from google.colab import files

wg.to_csv('SquadWages.csv')
files.download('SquadWages.csv')

# %%
last years standard stats table   stats_squads_standard_for

# %%
ly = pd.read_html('https://fbref.com/en/comps/9/2022-2023/2022-2023-Premier-League-Stats',
                  attrs={"id":"stats_squads_standard_for"}) [0]

# %%
pd.set_option('display.max_columns', None)

# %%
ly.columns = ['_'.join(col).strip() for col in ly.columns.values]

# %%
ly
# Out:
#    Unnamed: 0_level_0_Squad  Unnamed: 1_level_0_# Pl  Unnamed: 2_level_0_Age  \
# 0                   Arsenal                       26                    24.7
# 1               Aston Villa                       26                    27.0
# 2               Bournemouth                       31                    26.3
# 3                 Brentford                       25                    26.2
# 4                  Brighton                       29                    26.3
# 5                   Chelsea                       32                    26.3
# 6            Crystal Palace                       26                    26.7
# 7                   Everton                       28                    26.6
# 8                    Fulham                       29                    28.2
# 9              Leeds United                       29                    25.3
# 10           Leicester City                       28                    26.1
# ...

# %%
from google.colab import files

ly.to_csv('2022-2023SquadStats.csv')
files.download('2022-2023SquadStats.csv')
